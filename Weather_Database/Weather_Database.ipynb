# %%
# %matplotlib inline

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f864030b7219f496644943da56939fa4

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 605

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nyurba
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | berlevag
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | daru
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 1 | loja
# Processing Record 9 of Set 1 | batemans bay
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | bredasdorp
# Processing Record 12 of Set 1 | nanortalik
# Processing Record 13 of Set 1 | tiksi
# Processing Record 14 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 1 | ouegoa
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | nagod
# Processing Record 18 of Set 1 | nyagan
# Processing Record 19 of Set 1 | adrar
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | bathsheba
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | buala
# Processing Record 28 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | chokurdakh
# Processing Record 31 of Set 1 | norman wells
# Processing Record 32 of Set 1 | saskylakh
# Processing Record 33 of Set 1 | harper
# Processing Record 34 of Set 1 | tateyama
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | popovo
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | pijijiapan
# Processing Record 42 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 1 | cidreira
# Processing Record 44 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 1 | namtsy
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | touros
# Processing Record 48 of Set 1 | luderitz
# Processing Record 49 of Set 1 | merritt island
# Processing Record 50 of Set 1 | lebu
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | santa rosa
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | cordoba
# Processing Record 5 of Set 2 | upernavik
# Processing Record 6 of Set 2 | kikwit
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | bilibino
# Processing Record 9 of Set 2 | mecca
# Processing Record 10 of Set 2 | khandagayty
# Processing Record 11 of Set 2 | seymchan
# Processing Record 12 of Set 2 | los llanos de aridane
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | albany
# Processing Record 16 of Set 2 | brae
# Processing Record 17 of Set 2 | kavieng
# Processing Record 18 of Set 2 | manjacaze
# Processing Record 19 of Set 2 | benguela
# Processing Record 20 of Set 2 | zhigansk
# Processing Record 21 of Set 2 | thompson
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | souillac
# Processing Record 24 of Set 2 | yichang
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | vestmannaeyjar
# Processing Record 27 of Set 2 | torbay
# Processing Record 28 of Set 2 | cockburn town
# Processing Record 29 of Set 2 | halifax
# Processing Record 30 of Set 2 | gravdal
# Processing Record 31 of Set 2 | saint joseph
# Processing Record 32 of Set 2 | vila franca do campo
# Processing Record 33 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | dali
# Processing Record 36 of Set 2 | yenagoa
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | ixtapa
# Processing Record 40 of Set 2 | gilgit
# Processing Record 41 of Set 2 | sao filipe
# Processing Record 42 of Set 2 | hobart
# Processing Record 43 of Set 2 | naze
# Processing Record 44 of Set 2 | lewistown
# Processing Record 45 of Set 2 | yulara
# Processing Record 46 of Set 2 | miyako
# Processing Record 47 of Set 2 | sistranda
# Processing Record 48 of Set 2 | karabuk
# Processing Record 49 of Set 2 | sitka
# Processing Record 50 of Set 2 | moscow
# Processing Record 1 of Set 3 | hansi
# Processing Record 2 of Set 3 | karratha
# Processing Record 3 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 3 | vao
# Processing Record 5 of Set 3 | mahon
# Processing Record 6 of Set 3 | alta gracia
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | pingliang
# Processing Record 9 of Set 3 | bambous virieux
# Processing Record 10 of Set 3 | dikson
# Processing Record 11 of Set 3 | barrow
# Processing Record 12 of Set 3 | nome
# Processing Record 13 of Set 3 | la asuncion
# Processing Record 14 of Set 3 | hermanus
# Processing Record 15 of Set 3 | dauphin
# Processing Record 16 of Set 3 | rafaela
# Processing Record 17 of Set 3 | launceston
# Processing Record 18 of Set 3 | east london
# Processing Record 19 of Set 3 | karnobat
# Processing Record 20 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 21 of Set 3 | kampong chhnang
# Processing Record 22 of Set 3 | nemuro
# Processing Record 23 of Set 3 | plastun
# Processing Record 24 of Set 3 | hohhot
# Processing Record 25 of Set 3 | kirakira
# Processing Record 26 of Set 3 | kodiak
# Processing Record 27 of Set 3 | tilichiki
# Processing Record 28 of Set 3 | banda aceh
# Processing Record 29 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 3 | jalingo
# Processing Record 31 of Set 3 | ibra
# Processing Record 32 of Set 3 | iqaluit
# Processing Record 33 of Set 3 | sakakah
# Processing Record 34 of Set 3 | payo
# Processing Record 35 of Set 3 | lagoa
# Processing Record 36 of Set 3 | luancheng
# Processing Record 37 of Set 3 | bela
# Processing Record 38 of Set 3 | nizwa
# Processing Record 39 of Set 3 | marawi
# Processing Record 40 of Set 3 | bonthe
# Processing Record 41 of Set 3 | farafangana
# Processing Record 42 of Set 3 | namibe
# Processing Record 43 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 3 | provideniya
# Processing Record 45 of Set 3 | freeport
# Processing Record 46 of Set 3 | nioro
# Processing Record 47 of Set 3 | keizer
# Processing Record 48 of Set 3 | diego de almagro
# Processing Record 49 of Set 3 | salalah
# Processing Record 50 of Set 3 | bow island
# Processing Record 1 of Set 4 | sandur
# Processing Record 2 of Set 4 | qaanaaq
# Processing Record 3 of Set 4 | sar-e pul
# Processing Record 4 of Set 4 | sines
# Processing Record 5 of Set 4 | cayenne
# Processing Record 6 of Set 4 | tecoanapa
# Processing Record 7 of Set 4 | codrington
# Processing Record 8 of Set 4 | ponta do sol
# Processing Record 9 of Set 4 | capreol
# Processing Record 10 of Set 4 | saldanha
# Processing Record 11 of Set 4 | sant feliu de guixols
# Processing Record 12 of Set 4 | havre-saint-pierre
# Processing Record 13 of Set 4 | ayan
# Processing Record 14 of Set 4 | yetholm
# City not found. Skipping...
# Processing Record 15 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 4 | mizan teferi
# Processing Record 17 of Set 4 | tranbjerg
# Processing Record 18 of Set 4 | kenai
# Processing Record 19 of Set 4 | saint george
# Processing Record 20 of Set 4 | narsaq
# Processing Record 21 of Set 4 | kempele
# Processing Record 22 of Set 4 | kortkeros
# Processing Record 23 of Set 4 | shahreza
# Processing Record 24 of Set 4 | klaksvik
# Processing Record 25 of Set 4 | mayor pablo lagerenza
# Processing Record 26 of Set 4 | kiunga
# Processing Record 27 of Set 4 | kapit
# Processing Record 28 of Set 4 | imbituba
# Processing Record 29 of Set 4 | pevek
# Processing Record 30 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 4 | hobyo
# Processing Record 32 of Set 4 | korla
# Processing Record 33 of Set 4 | avarua
# Processing Record 34 of Set 4 | tigil
# Processing Record 35 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 36 of Set 4 | kruisfontein
# Processing Record 37 of Set 4 | hualmay
# Processing Record 38 of Set 4 | tongzi
# Processing Record 39 of Set 4 | saint-philippe
# Processing Record 40 of Set 4 | lompoc
# Processing Record 41 of Set 4 | great bend
# Processing Record 42 of Set 4 | kozhva
# Processing Record 43 of Set 4 | alyangula
# Processing Record 44 of Set 4 | riyadh
# Processing Record 45 of Set 4 | acajutla
# Processing Record 46 of Set 4 | atbasar
# Processing Record 47 of Set 4 | maltahohe
# Processing Record 48 of Set 4 | road town
# Processing Record 49 of Set 4 | okhotsk
# Processing Record 50 of Set 4 | port elizabeth
# Processing Record 1 of Set 5 | southbridge
# Processing Record 2 of Set 5 | shache
# Processing Record 3 of Set 5 | sao gabriel da cachoeira
# Processing Record 4 of Set 5 | castro
# Processing Record 5 of Set 5 | fort nelson
# Processing Record 6 of Set 5 | bengkulu
# Processing Record 7 of Set 5 | kaitangata
# Processing Record 8 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 5 | acapulco
# Processing Record 10 of Set 5 | guanay
# Processing Record 11 of Set 5 | quatre cocos
# Processing Record 12 of Set 5 | laguna
# Processing Record 13 of Set 5 | manta
# Processing Record 14 of Set 5 | the valley
# Processing Record 15 of Set 5 | lhokseumawe
# Processing Record 16 of Set 5 | ambilobe
# Processing Record 17 of Set 5 | humaita
# Processing Record 18 of Set 5 | nezhinka
# Processing Record 19 of Set 5 | west wendover
# Processing Record 20 of Set 5 | ust-nera
# Processing Record 21 of Set 5 | knysna
# Processing Record 22 of Set 5 | camaqua
# Processing Record 23 of Set 5 | calabozo
# Processing Record 24 of Set 5 | lentekhi
# Processing Record 25 of Set 5 | taltal
# Processing Record 26 of Set 5 | nazareno
# Processing Record 27 of Set 5 | urozhaynoye
# Processing Record 28 of Set 5 | vila velha
# Processing Record 29 of Set 5 | lufilufi
# Processing Record 30 of Set 5 | qingan
# City not found. Skipping...
# Processing Record 31 of Set 5 | cabo san lucas
# Processing Record 32 of Set 5 | lambarene
# Processing Record 33 of Set 5 | longyearbyen
# Processing Record 34 of Set 5 | gat
# Processing Record 35 of Set 5 | rayong
# Processing Record 36 of Set 5 | rawson
# Processing Record 37 of Set 5 | avera
# Processing Record 38 of Set 5 | virginia beach
# Processing Record 39 of Set 5 | roald
# Processing Record 40 of Set 5 | fare
# Processing Record 41 of Set 5 | chinhoyi
# Processing Record 42 of Set 5 | uthal
# Processing Record 43 of Set 5 | arraias
# Processing Record 44 of Set 5 | istra
# Processing Record 45 of Set 5 | belen
# Processing Record 46 of Set 5 | yellandu
# Processing Record 47 of Set 5 | kununurra
# Processing Record 48 of Set 5 | prince rupert
# Processing Record 49 of Set 5 | lemnia
# Processing Record 50 of Set 5 | dingle
# Processing Record 1 of Set 6 | tambul
# City not found. Skipping...
# Processing Record 2 of Set 6 | fortuna
# Processing Record 3 of Set 6 | ozernovskiy
# Processing Record 4 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 6 | coihaique
# Processing Record 6 of Set 6 | pyinmana
# Processing Record 7 of Set 6 | caucaia
# Processing Record 8 of Set 6 | gambissara
# Processing Record 9 of Set 6 | chuy
# Processing Record 10 of Set 6 | kuva
# City not found. Skipping...
# Processing Record 11 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 12 of Set 6 | saint anthony
# Processing Record 13 of Set 6 | maldonado
# Processing Record 14 of Set 6 | mangrol
# Processing Record 15 of Set 6 | aprelevka
# Processing Record 16 of Set 6 | samaipata
# Processing Record 17 of Set 6 | kibaha
# Processing Record 18 of Set 6 | redlands
# Processing Record 19 of Set 6 | tuy hoa
# Processing Record 20 of Set 6 | vallenar
# Processing Record 21 of Set 6 | ossora
# Processing Record 22 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 23 of Set 6 | smithers
# Processing Record 24 of Set 6 | teahupoo
# Processing Record 25 of Set 6 | mayumba
# Processing Record 26 of Set 6 | seoul
# Processing Record 27 of Set 6 | acuexcomac
# Processing Record 28 of Set 6 | teluk nibung
# Processing Record 29 of Set 6 | kristianstad
# Processing Record 30 of Set 6 | carutapera
# Processing Record 31 of Set 6 | asyut
# Processing Record 32 of Set 6 | clyde river
# Processing Record 33 of Set 6 | tuatapere
# Processing Record 34 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 6 | dhidhdhoo
# Processing Record 36 of Set 6 | tongliao
# Processing Record 37 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 6 | camargo
# Processing Record 39 of Set 6 | vostok
# Processing Record 40 of Set 6 | mitsamiouli
# Processing Record 41 of Set 6 | guerrero negro
# Processing Record 42 of Set 6 | faanui
# Processing Record 43 of Set 6 | grand baie
# Processing Record 44 of Set 6 | la ronge
# Processing Record 45 of Set 6 | tuktoyaktuk
# Processing Record 46 of Set 6 | port-gentil
# Processing Record 47 of Set 6 | cabra
# Processing Record 48 of Set 6 | arman
# Processing Record 49 of Set 6 | kautokeino
# Processing Record 50 of Set 6 | santa maria
# Processing Record 1 of Set 7 | albion
# Processing Record 2 of Set 7 | santa isabel do rio negro
# Processing Record 3 of Set 7 | port hedland
# Processing Record 4 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 7 | zatoka
# Processing Record 6 of Set 7 | riberalta
# Processing Record 7 of Set 7 | ozinki
# Processing Record 8 of Set 7 | anantapur
# Processing Record 9 of Set 7 | bandar
# Processing Record 10 of Set 7 | gazanjyk
# Processing Record 11 of Set 7 | lavrentiya
# Processing Record 12 of Set 7 | cap malheureux
# Processing Record 13 of Set 7 | davila
# Processing Record 14 of Set 7 | mayo
# Processing Record 15 of Set 7 | leningradskiy
# Processing Record 16 of Set 7 | victoria
# Processing Record 17 of Set 7 | pangnirtung
# Processing Record 18 of Set 7 | marsh harbour
# Processing Record 19 of Set 7 | bierun
# Processing Record 20 of Set 7 | alice springs
# Processing Record 21 of Set 7 | coihueco
# Processing Record 22 of Set 7 | hami
# Processing Record 23 of Set 7 | severo-kurilsk
# Processing Record 24 of Set 7 | chippewa falls
# Processing Record 25 of Set 7 | olafsvik
# Processing Record 26 of Set 7 | lagos
# Processing Record 27 of Set 7 | whitehorse
# Processing Record 28 of Set 7 | belyy yar
# Processing Record 29 of Set 7 | daguma
# Processing Record 30 of Set 7 | daytona beach
# Processing Record 31 of Set 7 | cairns
# Processing Record 32 of Set 7 | samarai
# Processing Record 33 of Set 7 | sinegorye
# Processing Record 34 of Set 7 | sorland
# Processing Record 35 of Set 7 | ahipara
# Processing Record 36 of Set 7 | matay
# Processing Record 37 of Set 7 | bilma
# Processing Record 38 of Set 7 | hollins
# Processing Record 39 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 7 | mattru
# Processing Record 41 of Set 7 | taoudenni
# Processing Record 42 of Set 7 | maningrida
# Processing Record 43 of Set 7 | anklam
# Processing Record 44 of Set 7 | tulun
# Processing Record 45 of Set 7 | rio gallegos
# Processing Record 46 of Set 7 | ancud
# Processing Record 47 of Set 7 | esperance
# Processing Record 48 of Set 7 | schwandorf
# Processing Record 49 of Set 7 | bejar
# Processing Record 50 of Set 7 | sao mateus
# Processing Record 1 of Set 8 | ndiekro
# City not found. Skipping...
# Processing Record 2 of Set 8 | tunoshna
# Processing Record 3 of Set 8 | te anau
# Processing Record 4 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 5 of Set 8 | ramban
# Processing Record 6 of Set 8 | solnechnyy
# Processing Record 7 of Set 8 | siguiri
# Processing Record 8 of Set 8 | kosh-agach
# Processing Record 9 of Set 8 | bandarbeyla
# Processing Record 10 of Set 8 | ferrol
# Processing Record 11 of Set 8 | puerto escondido
# Processing Record 12 of Set 8 | nishihara
# Processing Record 13 of Set 8 | rantoul
# Processing Record 14 of Set 8 | guangyuan
# Processing Record 15 of Set 8 | mancio lima
# Processing Record 16 of Set 8 | itarema
# Processing Record 17 of Set 8 | vzmorye
# Processing Record 18 of Set 8 | lishui
# Processing Record 19 of Set 8 | gondar
# Processing Record 20 of Set 8 | bud
# Processing Record 21 of Set 8 | pangkalanbuun
# Processing Record 22 of Set 8 | camacha
# Processing Record 23 of Set 8 | turayf
# Processing Record 24 of Set 8 | jarjis
# City not found. Skipping...
# Processing Record 25 of Set 8 | ribeira grande
# Processing Record 26 of Set 8 | estepona
# Processing Record 27 of Set 8 | wapi pathum
# Processing Record 28 of Set 8 | poum
# Processing Record 29 of Set 8 | ulcinj
# Processing Record 30 of Set 8 | zyryanka
# Processing Record 31 of Set 8 | menongue
# Processing Record 32 of Set 8 | sao joao da barra
# Processing Record 33 of Set 8 | granville
# Processing Record 34 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 35 of Set 8 | haines junction
# Processing Record 36 of Set 8 | kayerkan
# Processing Record 37 of Set 8 | cortez
# Processing Record 38 of Set 8 | hofn
# Processing Record 39 of Set 8 | vanavara
# Processing Record 40 of Set 8 | yeppoon
# Processing Record 41 of Set 8 | morondava
# Processing Record 42 of Set 8 | vila
# Processing Record 43 of Set 8 | san quintin
# Processing Record 44 of Set 8 | kyra
# Processing Record 45 of Set 8 | sambava
# Processing Record 46 of Set 8 | nalut
# Processing Record 47 of Set 8 | dengzhou
# Processing Record 48 of Set 8 | marzuq
# Processing Record 49 of Set 8 | marfino
# Processing Record 50 of Set 8 | saint-pierre
# Processing Record 1 of Set 9 | omsukchan
# Processing Record 2 of Set 9 | chulym
# Processing Record 3 of Set 9 | kumla
# Processing Record 4 of Set 9 | borsad
# Processing Record 5 of Set 9 | kahului
# Processing Record 6 of Set 9 | san cristobal
# Processing Record 7 of Set 9 | hvolsvollur
# Processing Record 8 of Set 9 | biak
# Processing Record 9 of Set 9 | ca mau
# Processing Record 10 of Set 9 | rovaniemi
# Processing Record 11 of Set 9 | hasaki
# Processing Record 12 of Set 9 | santa cruz
# Processing Record 13 of Set 9 | beringovskiy
# Processing Record 14 of Set 9 | beloha
# Processing Record 15 of Set 9 | oktyabrskoye
# Processing Record 16 of Set 9 | mundo nuevo
# Processing Record 17 of Set 9 | bethanien
# Processing Record 18 of Set 9 | yatou
# Processing Record 19 of Set 9 | beaupre
# Processing Record 20 of Set 9 | denpasar
# Processing Record 21 of Set 9 | naron
# Processing Record 22 of Set 9 | tinqueux
# Processing Record 23 of Set 9 | ust-kuyga
# Processing Record 24 of Set 9 | lorengau
# Processing Record 25 of Set 9 | olavarria
# Processing Record 26 of Set 9 | saint-augustin
# Processing Record 27 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 9 | ponta delgada
# Processing Record 29 of Set 9 | bansdih
# Processing Record 30 of Set 9 | cabo rojo
# Processing Record 31 of Set 9 | bethel
# Processing Record 32 of Set 9 | khorinsk
# Processing Record 33 of Set 9 | mweka
# Processing Record 34 of Set 9 | ankazoabo
# Processing Record 35 of Set 9 | talnakh
# Processing Record 36 of Set 9 | suntar
# Processing Record 37 of Set 9 | lensk
# Processing Record 38 of Set 9 | alirajpur
# Processing Record 39 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 40 of Set 9 | grindavik
# Processing Record 41 of Set 9 | geraldton
# Processing Record 42 of Set 9 | mackay
# Processing Record 43 of Set 9 | simao
# Processing Record 44 of Set 9 | baturaja
# Processing Record 45 of Set 9 | benghazi
# Processing Record 46 of Set 9 | aden
# Processing Record 47 of Set 9 | isangel
# Processing Record 48 of Set 9 | vardo
# Processing Record 49 of Set 9 | myanaung
# Processing Record 50 of Set 9 | belmonte
# Processing Record 1 of Set 10 | mantamados
# Processing Record 2 of Set 10 | venado tuerto
# Processing Record 3 of Set 10 | la rioja
# Processing Record 4 of Set 10 | tirat karmel
# Processing Record 5 of Set 10 | sangar
# Processing Record 6 of Set 10 | vamospercs
# Processing Record 7 of Set 10 | san patricio
# Processing Record 8 of Set 10 | alta floresta
# Processing Record 9 of Set 10 | umm lajj
# Processing Record 10 of Set 10 | georgetown
# Processing Record 11 of Set 10 | batticaloa
# Processing Record 12 of Set 10 | atar
# Processing Record 13 of Set 10 | tura
# Processing Record 14 of Set 10 | cabatuan
# Processing Record 15 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 10 | silifke
# Processing Record 17 of Set 10 | mackenzie
# Processing Record 18 of Set 10 | san jeronimito
# Processing Record 19 of Set 10 | bestobe
# Processing Record 20 of Set 10 | ligayan
# Processing Record 21 of Set 10 | sept-iles
# Processing Record 22 of Set 10 | tocopilla
# Processing Record 23 of Set 10 | labuhan
# Processing Record 24 of Set 10 | maoming
# Processing Record 25 of Set 10 | seredeyskiy
# Processing Record 26 of Set 10 | honiara
# Processing Record 27 of Set 10 | huarmey
# Processing Record 28 of Set 10 | fairbanks
# Processing Record 29 of Set 10 | katsuura
# Processing Record 30 of Set 10 | port blair
# Processing Record 31 of Set 10 | baiyin
# Processing Record 32 of Set 10 | dalbandin
# Processing Record 33 of Set 10 | chicama
# Processing Record 34 of Set 10 | riachao das neves
# Processing Record 35 of Set 10 | inverell
# Processing Record 36 of Set 10 | galle
# Processing Record 37 of Set 10 | bosaso
# Processing Record 38 of Set 10 | south sioux city
# Processing Record 39 of Set 10 | komsomolskiy
# Processing Record 40 of Set 10 | torata
# Processing Record 41 of Set 10 | ilulissat
# Processing Record 42 of Set 10 | kasama
# Processing Record 43 of Set 10 | morro da fumaca
# Processing Record 44 of Set 10 | constitucion
# Processing Record 45 of Set 10 | ballangen
# Processing Record 46 of Set 10 | yanagawa
# Processing Record 47 of Set 10 | kaduy
# Processing Record 48 of Set 10 | conceicao do almeida
# Processing Record 49 of Set 10 | saint-francois
# Processing Record 50 of Set 10 | veinticinco de mayo
# Processing Record 1 of Set 11 | vaitape
# Processing Record 2 of Set 11 | george
# Processing Record 3 of Set 11 | zapolyarnyy
# Processing Record 4 of Set 11 | omboue
# Processing Record 5 of Set 11 | nueva loja
# Processing Record 6 of Set 11 | meulaboh
# Processing Record 7 of Set 11 | crotone
# Processing Record 8 of Set 11 | rundu
# Processing Record 9 of Set 11 | paraisopolis
# Processing Record 10 of Set 11 | biga
# Processing Record 11 of Set 11 | pokhara
# Processing Record 12 of Set 11 | wuwei
# Processing Record 13 of Set 11 | yangjiang
# Processing Record 14 of Set 11 | ambon
# Processing Record 15 of Set 11 | puro
# Processing Record 16 of Set 11 | xiongyue
# Processing Record 17 of Set 11 | gizo
# Processing Record 18 of Set 11 | faya
# Processing Record 19 of Set 11 | el viejo
# Processing Record 20 of Set 11 | chapais
# Processing Record 21 of Set 11 | nampula
# Processing Record 22 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 11 | makakilo city
# Processing Record 24 of Set 11 | scottsbluff
# Processing Record 25 of Set 11 | port keats
# Processing Record 26 of Set 11 | kieta
# Processing Record 27 of Set 11 | norton shores
# Processing Record 28 of Set 11 | svetlogorsk
# Processing Record 29 of Set 11 | zhangye
# Processing Record 30 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 11 | ola
# Processing Record 32 of Set 11 | anadyr
# Processing Record 33 of Set 11 | providencia
# Processing Record 34 of Set 11 | mahebourg
# Processing Record 35 of Set 11 | homer
# Processing Record 36 of Set 11 | hamilton
# Processing Record 37 of Set 11 | shingu
# Processing Record 38 of Set 11 | tevaitoa
# Processing Record 39 of Set 11 | dubbo
# Processing Record 40 of Set 11 | krasnoarmeysk
# Processing Record 41 of Set 11 | namatanai
# Processing Record 42 of Set 11 | nanchong
# Processing Record 43 of Set 11 | igede
# Processing Record 44 of Set 11 | srandakan
# Processing Record 45 of Set 11 | storforshei
# Processing Record 46 of Set 11 | praia
# Processing Record 47 of Set 11 | bolshiye chapurniki
# City not found. Skipping...
# Processing Record 48 of Set 11 | rio brilhante
# Processing Record 49 of Set 11 | wenling
# Processing Record 50 of Set 11 | kondinskoye
# Processing Record 1 of Set 12 | anloga
# Processing Record 2 of Set 12 | ostrovnoy
# Processing Record 3 of Set 12 | taitung
# Processing Record 4 of Set 12 | tarko-sale
# Processing Record 5 of Set 12 | terra santa
# Processing Record 6 of Set 12 | derzhavinsk
# Processing Record 7 of Set 12 | tazovskiy
# Processing Record 8 of Set 12 | burnie
# Processing Record 9 of Set 12 | bartlesville
# Processing Record 10 of Set 12 | matara
# Processing Record 11 of Set 12 | celldomolk
# Processing Record 12 of Set 12 | college
# Processing Record 13 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 14 of Set 12 | alihe
# Processing Record 15 of Set 12 | devils lake
# Processing Record 16 of Set 12 | ojinaga
# Processing Record 17 of Set 12 | aklavik
# Processing Record 18 of Set 12 | noshiro
# Processing Record 19 of Set 12 | plettenberg bay
# Processing Record 20 of Set 12 | martapura
# Processing Record 21 of Set 12 | minab
# Processing Record 22 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 23 of Set 12 | zaysan
# Processing Record 24 of Set 12 | nurlat
# Processing Record 25 of Set 12 | thunder bay
# Processing Record 26 of Set 12 | palauig
# Processing Record 27 of Set 12 | dillingen
# Processing Record 28 of Set 12 | coquimbo
# Processing Record 29 of Set 12 | tumwater
# Processing Record 30 of Set 12 | kidal
# Processing Record 31 of Set 12 | shimoda
# Processing Record 32 of Set 12 | morant bay
# Processing Record 33 of Set 12 | ribeira brava
# Processing Record 34 of Set 12 | uvira
# Processing Record 35 of Set 12 | marquette
# Processing Record 36 of Set 12 | salvador
# Processing Record 37 of Set 12 | khash
# Processing Record 38 of Set 12 | richard toll
# City not found. Skipping...
# Processing Record 39 of Set 12 | bubaque
# Processing Record 40 of Set 12 | takoradi
# Processing Record 41 of Set 12 | walvis bay
# Processing Record 42 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 12 | arlit
# Processing Record 44 of Set 12 | chiapilla
# Processing Record 45 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 12 | navirai
# Processing Record 47 of Set 12 | broome
# Processing Record 48 of Set 12 | bloemfontein
# Processing Record 49 of Set 12 | sabang
# Processing Record 50 of Set 12 | soyo
# Processing Record 1 of Set 13 | mixtequilla
# City not found. Skipping...
# Processing Record 2 of Set 13 | auki
# Processing Record 3 of Set 13 | saint-ambroise
# Processing Record 4 of Set 13 | hesla
# Processing Record 5 of Set 13 | atascadero
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 562

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Nyurba  63.2842  118.3319     31.42        92          71        4.09
# 1  Busselton -33.6500  115.3333     53.01        88           1        1.16
# 2   Berlevag  70.8578   29.0864     34.79        75         100       16.44
# 3      Bluff -46.6000  168.3333     48.99        78          82        8.01
# 4       Daru  -9.0763  143.2092     80.04        84          85        5.53
#
#   Current Description Country                 Date
# 0       broken clouds      RU  2021-04-24 17:22:13
# 1           clear sky      AU  2021-04-24 17:20:13
# 2     overcast clouds      NO  2021-04-24 17:22:13
# 3          light rain      NZ  2021-04-24 17:18:34
# 4       moderate rain      PG  2021-04-24 17:22:13

# %%
new_column_order = ["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#         City Country                 Date      Lat       Lng  Max Temp  \
# 0     Nyurba      RU  2021-04-24 17:22:13  63.2842  118.3319     31.42
# 1  Busselton      AU  2021-04-24 17:20:13 -33.6500  115.3333     53.01
# 2   Berlevag      NO  2021-04-24 17:22:13  70.8578   29.0864     34.79
# 3      Bluff      NZ  2021-04-24 17:18:34 -46.6000  168.3333     48.99
# 4       Daru      PG  2021-04-24 17:22:13  -9.0763  143.2092     80.04
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        92          71        4.09       broken clouds
# 1        88           1        1.16           clear sky
# 2        75         100       16.44     overcast clouds
# 3        78          82        8.01          light rain
# 4        84          85        5.53       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
